# %% [markdown]
# # Prepare data for model

# %%
from chatbot_handler import Chatbot
from langchain.text_splitter import CharacterTextSplitter
from langchain.document_loaders import DirectoryLoader
from langchain.document_loaders import TextLoader


from helpers.constants import Constants

from helpers.lookups import Path

import os

# %%
def split_directory(directory_path, separator):
    docs = []

    c_splitter = CharacterTextSplitter(
        chunk_size = 10,
        chunk_overlap = 5,
        separator=separator.value
    )


    # Iterate over the scraped data
    for filename in os.listdir(directory_path):
        if filename.endswith(".txt"):  # Filter only text files
            file_path = os.path.join(directory_path, filename)

            # Load the text file
            loader = TextLoader(file_path)
            text = loader.load()

            # Split into chunks
            docs.append(c_splitter.split_documents(text))

    return docs

# %%
docs = split_directory(Path.ScrapedText.value, Constants.TextSeparator)
# Out:
# Created a chunk of size 5520, which is longer than the specified 10
# Created a chunk of size 1389, which is longer than the specified 10
# Created a chunk of size 2133, which is longer than the specified 10
# Created a chunk of size 236, which is longer than the specified 10
# Created a chunk of size 4679, which is longer than the specified 10
# Created a chunk of size 1368, which is longer than the specified 10
# Created a chunk of size 819, which is longer than the specified 10
# Created a chunk of size 481, which is longer than the specified 10
# Created a chunk of size 395, which is longer than the specified 10
# Created a chunk of size 2254, which is longer than the specified 10
# Created a chunk of size 1599, which is longer than the specified 10
# Created a chunk of size 1245, which is longer than the specified 10
# Created a chunk of size 435, which is longer than the specified 10
# Created a chunk of size 196, which is longer than the specified 10
# ...

# %%
# Out:
# 8

# %%
c_splitter = CharacterTextSplitter(
    chunk_size = 10,
    chunk_overlap = 5,
    separator=Constants.TextSeparator.value
)
    
n_docs = c_splitter.split_documents(docs)

# %%
len(n_docs)
# Out:
# 7

# %%
text="testing the code" + Constants.TextSeparator.value + "testing here again"

# %%
c_splitter.split_text(text)
# Out:
# Created a chunk of size 16, which is longer than the specified 10
# ['testing the code', 'testing here again']

# %%
loader_admission = UnstructuredFileLoader("./data/scraped_text/admission.txt")
docs = loader_admission.load()

# %% [markdown]
# ## Load scraped data dir

# %%
loader = DirectoryLoader(Path.ScrapedText.value)

# %%
docs = loader.load()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ronan.tanios\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.

# %% [markdown]
# ## Split doc

# %%
for doc in docs:

# %% [markdown]
# ## Load PDF
